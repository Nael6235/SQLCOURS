# %%
import pyodbc
import pandas as pd

# %%
connection = pyodbc.connect('Driver={SQL Server};'
                            'Server=LAPTOP-AOUDEC8K\SQLEXPRESS;'
                            'Database=ODS;'
                            'Trusted_Connection=yes;')

# %%
cursor = connection.cursor()

create_table_query = """
SELECT * FROM BNLC ;
"""
result = cursor.execute(create_table_query).fetchall()

pd.DataFrame.from_records(result)
# Out:
#                0     1                                             2   \
# 0     01301-C-002  None                            Parking Quinconces
# 1     01350-C-001  None    Terrain de Boules - Chemin des Lyonni+®res
# 2     01376-C-001  None  Aire de covoiturage Saint-Maurice-De-Beynost
# 3     01405-C-001  None                            Parking des Sports
# 4     01422-C-001  None                          Place de La Fontaine
# ...           ...   ...                                           ...
# 8642  66175-C-001  None            Aire de Saint-G+®nis-des-Fontaines
# 8643  49018-C-006  None   Parking de la mairie - Saint Martin d'Arc+®
# 8644  33000-C-001     1                                   Villandraut
# 8645  66069-C-001  None        Aire de covoiturage d'Espira de l'Agly
# 8646  66008-C-003  None       Aire de covoiturage Christian Bourquin
#
#                                                      3   \
# 0                      Route De Chamonin - "Quinconces"
# 1            Chemin Des Lyonni+®res - Terrain De Boules
# 2                              Saint-Maurice-De-Beynost
# 3                            D1083 - Parking Des Sports
# 4             Place De La Fontaine- Anciens Combattants
# ...                                                 ...
# 8642                      D618 - Echangeur de St-G+®nis
# 8643                                    8 VC Grande rue
# 8644                                      3 villandraut
# 8645                  RD117  - direction Cases-de-P+¿ne
# 8646  Sortie n-¦10 de la 2x2 voies (RD914) ÔÇô direc...
#
#                              4      5                    6           7     8   \
# 0                       POLLIAT  01301              Parking  2019-08-29  true
# 1            ST ETIENNE DU BOIS  01350              Parking  2019-08-29  true
# 2         ST MAURICE DE BEYNOST  01376   Sortie d'autoroute  2019-08-29  true
# 3                        SERVAS  01405              Parking  2019-08-29  true
# 4                       TOSSIAT  01422              Parking  2019-08-29  true
# ...                         ...    ...                  ...         ...   ...
# 8642  SAINT-GENIS-DES-FONTAINES  66175  Aire de covoiturage  2022-08-05  true
# 8643             BAUGE EN ANJOU  49018              Parking  2022-08-17  true
# 8644                villandraut  33000  Aire de covoiturage  2021-11-02  true
# 8645           ESPIRA-DE-L'AGLY  66069  Aire de covoiturage  2022-10-12  true
# 8646           ARGELES SUR MER   66008  Aire de covoiturage  2022-10-10  true
#
#              9                  10                  11  12    13    14    15  \
# 0     200071751           5.121596           46.250066   6  None  None  None
# 1     200071751        5.289722222         46.28322222   5  None  None  None
# 2     240100800           4.989172           45.820935  80  None  None  None
# 3     200071751        5.163272222         46.13119722   3  None  None  None
# 4     200071751        5.316269444         46.14157222   1  None  None  None
# ...         ...                ...                 ...  ..   ...   ...   ...
# 8642  226600013   2.91886682866195    42.5488485334644   7     1  None  None
# 8643  244900882          -0.085044            47.55954  45     1  None  None
# 8644       None          -0.371283           44.457274  10     3  None  24/7
# 8645  226600013   2.82463737398696   42.77777420590214  13     1  None  24/7
# 8646  226600013  3.00629718122744   42.56353596223298   23     0  None  24/7
#
#                              16     17  \
# 0                          None   None
# 1                          None   None
# 2                          None   None
# 3                          None   None
# 4                          None   None
# ...                         ...    ...
# 8642  Conseil D+®partemental 66  false
# 8643                      Ville   true
# 8644                    Commune  false
# 8645  Conseil D+®partemental 66  false
# 8646  Conseil D+®partemental 66   None
#
#                                                  18
# 0                                              None
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                              None
# ...                                             ...
# 8642                                           None
# 8643                                           None
# 8644                                           None
# 8645                                           None
# 8646  aire coll+®e +á l'aire multimodale du lyc+®e
#
# [8647 rows x 19 columns]
